# %% [markdown]
# ### Scenario 1 (Base Case): 4% Uniform DF (Why did you go for 4% in Balmorel ?) (avg 2000-2013)
# ### Scenario 2 (Low Case): 2% Uniform DF (2013 - 2022) (previously 2%)
# ### Scenario 3 (High Case): 9% Uniform DF (avg 1985-1995) (previously 7%)
# ### Scenario 4 (Country-specific Case): Annuity changed using external source

# %% [markdown]
# # Base Case scenario overview

# %% [markdown]
# ### Generation mix

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Create a dictionary to map each country to a country group
country_groupings = {
    "Iberia": ["PORTUGAL", "SPAIN"],
    "UK": ["IRELAND", "UNITED_KINGDOM"],
    "Nordic countries": ["DENMARK", "FINLAND", "NORWAY", "SWEDEN"],
    "Baltics": ["ESTONIA", "LATVIA", "LITHUANIA"],
    "Central Europe": ["GERMANY", "LUXEMBOURG", "NETHERLANDS", "SWITZERLAND"],
    "Eastern EU": ["AUSTRIA", "CZECH_REPUBLIC", "POLAND"],
    "South Eastern EU": ["BULGARIA", "CROATIA", "CYPRUS", "GREECE", "HUNGARY", "MALTA", "ROMANIA", "SLOVAKIA", "SLOVENIA"],
    "South Eastern non-EU": ["ALBANIA", "BOSNIA_AND_HERZEGOVINA", "NORTH_MACEDONIA", "MONTENEGRO", "SERBIA"],
    "Mediterranean": ["ITALY"],
    "Franco-Belgium": ["BELGIUM", "FRANCE"]
}

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Just more natgas when we consider heat as well, especially in Centrale Europe and Meditarean countries

# %% [markdown]
# ### Hydrogen

# %% [markdown]
# Insert mqp of demand assumptions

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In 2050, mostly electrolysis developped, with a predominence in Central Europe and Iberia. . Imports from north africa through Mediterannea and Iberia

# %% [markdown]
# # Sensitivity to DR assumptions

# %% [markdown]
# ## Uniform Discount rate

# %% [markdown]
# ### Capacities:
# The lower the DR, the higher the overall cap, but only in the coming years. If you look at 2050, need a lot of cap again, even for high DR

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Because of Hydrogen fuel (it corresponds to storages in H2 right?)
#
# Not electric only, everything

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Without H2 storage, the higher the DR the lower the gen capacity needed

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# More dependant on NatGas, less on Sun and Wind

# %% [markdown]
# only electric now:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Per location:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# As RES can't be put anywhere, we would need a more interconnected network, so more transmission capacities

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Hydrogen

# %% [markdown]
# Generation cap

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# and prod

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# why total prod are different? endogenous diff?

# %% [markdown]
# and transmission capacities for H2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# prod total doit etre la meme, mais plus on va vers SMR, moins la cap totale est elevee

# %% [markdown]
# low DR, plus de SMR?

# %% [markdown]
# The more you incresase DR:
# - the more UK and france is shifted to Germany Poland and Italy
# - Iports are not a variable for now
# - the more SMR is used
# - the less echanges are made (car on peut mettre des SMR ou on veut)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# sans imports, qu'est ce que ca donne? Balopt.opt, sans 3rd countries
# grosse diff?

# %% [markdown]
# ### (Total emissions)
# rapide mais interessant (ordre de grandeur)

# %% [markdown]
# ### (Electricity prices)

# %% [markdown]
# ## Country specific discount rate

# %% [markdown]
# ### Scenarios:
# - Predicted DR according to litt
# - High DR in South Estern EU (a verifier)
# - Low DR in the Baltics
# - High DR in Southern EU (Russie?)
#
# chercher etudes
# les coupler?

# %% [markdown]
# Country groupings to do the analysis:
# - UK
# - France
# - Iberia (Sapin and Portugal)
# - Italy
# - Benelux
# - Germany
# - Poland
# - Central
# - Nordics (Denmark, Sweden, Norway)
# - Nord-East ()
# - South east
# - (Imports)

# %% [markdown]
# ### Maps illustrating the different DR accross countries
