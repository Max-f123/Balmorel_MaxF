# %% [markdown]
# # Scenarios
# Low: 1% Uniform DF
#
# Social: 3.3% Uniform DF
#
# Base Case: 4% Uniform DF
#
# Private: 5.7% Uniform DF
#
# High: 9% Uniform DF
#
# Social CS: Social country specific DF
#
# Private CS: Private country specific DF

# %% [markdown]
# # Base Line

# %% [markdown]
# ### Generation mix

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Hydrogen

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Uniform DR

# %% [markdown]
# ### Generation Mix

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# As RES can't be put anywhere, we would need a more interconnected network, so more transmission capacities

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Hydrogen

# %% [markdown]
# demand

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# How does it compare with other forecasts?
#
# Why more demand with high DR?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Why more endo_fuel cell from H2 with high DR???

# %% [markdown]
# Generation cap

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Shifts from 1 region to another

# %% [markdown]
# and prod

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# why total prod are different? endogenous diff?

# %% [markdown]
# why high DF produce more H2

# %% [markdown]
# and transmission capacities for H2
# storage, losses?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# prod total doit etre la meme, mais plus on va vers SMR, moins la cap totale est elevee

# %% [markdown]
# low DR, plus de SMR?

# %% [markdown]
# National CAP change from high to low

# %% [markdown]
# The more you incresase DR:
# - the more UK and france is shifted to Germany Poland and Italy
# - Iports are not a variable for now
# - the more SMR is used
# - the less echanges are made (car on peut mettre des SMR ou on veut)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# sans imports, qu'est ce que ca donne? Balopt.opt, sans 3rd countries
# grosse diff?

# %% [markdown]
# ### Total emissions
# Significant impact, with all regions behind almost proportionnaly increased

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### (Electricity prices)

# %% [markdown]
# ## Country specific discount rate

# %% [markdown]
# ### Scenarios:
# - Predicted DR according to litt
# - High DR in South Estern EU (a verifier)
# - Low DR in the Baltics
# - High DR in Southern EU (Russie?)
#
# chercher etudes
# les coupler?

# %% [markdown]
# Country groupings to do the analysis:
# - UK
# - France
# - Iberia (Sapin and Portugal)
# - Italy
# - Benelux
# - Germany
# - Poland
# - Central
# - Nordics (Denmark, Sweden, Norway)
# - Nord-East ()
# - South east
# - (Imports)

# %% [markdown]
# ### Maps illustrating the different DR accross countries

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# But largely biased by H2 storage
#
# Without:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # RES MIX

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# but one could think that such big effects happen only in the long term because discount rates have a long term impact, so it's normal that if we look at 2050 it's gonna be a big difference... Look at 2030! => Iberia, South estearn no EU and franco belgium almost double! While Mediterranean takes +20GW!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# and for wind? a bit less sensitive, even thought Mediterannean doubles while Nordic countries and centrale EU lose 20 GW each!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # H2 Production

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### H2 capacities

# %% [markdown]
# ### ELZ

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Interesting to see not only the long term impact, but also short term

# %% [markdown]
# Interesting to see that the bigger impacts happens in CEntral Europe, where the local DR "only changed" by 0.33% between the two scenarios, when in the Eastern EU in changed way more in terms of % but had a way lower imapct on results => interconnectivity of the network!

# %% [markdown]
# ### NatGas

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Elec prices? Emissions? Transmission?
