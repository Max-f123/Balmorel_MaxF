# %%
import sys
import gams
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from statsmodels.nonparametric.smoothers_lowess import lowess
#import gdxpds
from pandas.api.types import CategoricalDtype

# Get the absolute path of the Pybalmorel folder
pybalmorel_path = os.path.abspath("/Users/maxfavrot/Balmorel/pybalmorel_MaxF")

# Set the correct path for GAMS
gams_path = "/Library/Frameworks/GAMS.framework/Versions/48/Resources"

# Add Pybalmorel to Python's module search path
if pybalmorel_path not in sys.path:
    sys.path.insert(0, pybalmorel_path)

# Now, you can import your modules
from src.pybalmorel import MainResults
from src.pybalmorel.utils import symbol_to_df

# Set environment variables
os.environ["PATH"] = gams_path + ":" + os.environ.get("PATH", "")
os.environ["DYLD_LIBRARY_PATH"] = gams_path + ":" + os.environ.get("DYLD_LIBRARY_PATH", "")

# %% [markdown]
# # Loading the data

# %% [markdown]
# ## Balmorel Results

# %%
res_I_II = MainResults(files=['MainResults_1.gdx', 'MainResults_3.gdx', 'MainResults_4.gdx', 'MainResults_5.gdx', 'MainResults_7.gdx'], paths='../../main_results/current/MainResults', scenario_names=['DR-1', 'DR-3', 'BaseCase', 'DR-5', 'DR-7'])
# Out:
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_1.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_3.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_4.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_5.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_7.gdx

# %%
res_III = MainResults(files=['MainResults_4.gdx', 'MainResults_4_Private.gdx', 'MainResults_5_4.gdx' ], paths='../../main_results/current/MainResults', scenario_names=['Public', 'Private', '5_4' ])
# Out:
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_4.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_4_Private.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_5_4.gdx

# %% [markdown]
# ## Optiflow Results

# %%
res_I_II_opti = MainResults(files=['MainResults_1.gdx', 'MainResults_3.gdx', 'MainResults_4.gdx', 'MainResults_5.gdx', 'MainResults_7.gdx'], paths='../../main_results/current/MainResults', scenario_names=['DR-1', 'DR-3', 'BaseCase', 'DR-5', 'DR-7'], result_type='optiflow')
# Out:
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_1.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_3.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_4.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_5.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_7.gdx

# %%
res_III_opti = MainResults(files=['MainResults_4.gdx', 'MainResults_4_Private.gdx', 'MainResults_5_4.gdx' ], paths='../../main_results/current/MainResults', scenario_names=['Public', 'Private', 5_4 ], result_type='optiflow')
# Out:
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_4.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_4_Private.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_5_4.gdx

# %% [markdown]
# # Section I

# %% [markdown]
# ### Appendix, Cap_El_Base

# %%
res_I_II.interactive_bar_chart()
# Out:
# Result type: balmorel
# GridBox(children=(Dropdown(description='Table:', layout=Layout(width='80%'), options=('F_CONS_YCRA', 'F_CONS_Y…
# Output()
# Stack(children=(GridBox(children=(SelectMultiple(description='Scenario', index=(0,), layout=Layout(height='99%…
# Output()
# ...
# Output()
# HBox()
# Output()
# ...
# Output()
# Output()

# %% [markdown]
# ### Prod_El_Base

# %%
res_I_II.interactive_bar_chart()
# Out:
# Result type: balmorel
# GridBox(children=(Dropdown(description='Table:', layout=Layout(width='80%'), options=('F_CONS_YCRA', 'F_CONS_Y…
# Output()
# Stack(children=(GridBox(children=(SelectMultiple(description='Scenario', index=(0,), layout=Layout(height='99%…
# Output()
# ...
# Output()
# HBox()
# Output()
# ...
# Output()
# Output()

# %% [markdown]
# ### Map_El_Base

# %%
fig, ax = res_I_II.plot_map(scenario='BaseCase', year=2050, commodity='Electricity', lines='FlowYear', generation='Production'
                       , generation_var = 'FFF', 
                       generation_show_min = 8   # Plot less categories in the legend
                       )
# Out:
# Found MainResults in ../../main_results/current/MainResults/MainResults_B_4%.gdx
# /Users/maxfavrot/Balmorel/pybalmorel_MaxF/src/pybalmorel/plotting/maps_balmorel.py:808: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_line_new = pd.concat([df_line_new, df_line.loc[[k]]], ignore_index=True)

# %% [markdown]
# ### Cap_H2_Base

# %%
res_I_II.interactive_bar_chart()
# Out:
# Result type: balmorel
# GridBox(children=(Dropdown(description='Table:', layout=Layout(width='80%'), options=('F_CONS_YCRA', 'F_CONS_Y…
# Output()
# Stack(children=(GridBox(children=(SelectMultiple(description='Scenario', index=(0,), layout=Layout(height='99%…
# Output()
# ...
# Output()
# HBox()
# Output()
# ...
# Output()
# Output()

# %% [markdown]
# ### Prod_H2_Base

# %%
res_I_II.interactive_bar_chart()
# Out:
# Result type: balmorel
# GridBox(children=(Dropdown(description='Table:', layout=Layout(width='80%'), options=('F_CONS_YCRA', 'F_CONS_Y…
# Output()
# Stack(children=(GridBox(children=(SelectMultiple(description='Scenario', index=(0,), layout=Layout(height='99%…
# Output()
# ...
# Output()
# HBox()
# Output()
# ...
# Output()
# Output()

# %% [markdown]
# ### Map_H2_Base

# %%
fig, ax = res_I_II.plot_map(scenario='BaseCase', year=2050, commodity='Hydrogen', lines='FlowYear', generation='Production'
                         ,line_width_max= 8, pie_radius_max = 1.5
                         , line_legend_cluster_values=[10, 30, 60, 100], pie_legend_cluster_values=[25, 50, 100, 200])
# Out:
# Found MainResults in ../../main_results/current/MainResults/MainResults_B_4%.gdx
# /Users/maxfavrot/Balmorel/pybalmorel_MaxF/src/pybalmorel/plotting/maps_balmorel.py:814: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_line_new = pd.concat([df_line_new, df_line.loc[[i]]], ignore_index=True)

# %% [markdown]
# ### Map_H2_Export_2050

# %%
fig, ax = res_I_II.plot_map(scenario='BaseCase', year=2050,
                       background="H2 Net Export", background_scale_tick = 10)
# Out:
# Found MainResults in ../../main_results/current/MainResults/MainResults_4.gdx
# generation_commodity must be either "Electricity" or "Hydrogen", set to None
# /Users/maxfavrot/Balmorel/pybalmorel_MaxF/src/pybalmorel/plotting/maps_balmorel.py:1062: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_background_netexport = pd.concat([df_background_netexport, pd.DataFrame([{'RRR': rrr, 'Value': net_export}])], ignore_index=True)

# %%
fig, ax = res_I_II.plot_profile(scenario='BaseCase', year=2030, commodity='Electricity', columns='Technology', region='DK1')

# %%
fig, ax = res_I_II.plot_profile(scenario='BaseCase', year=2030, commodity='Hydrogen', columns='Technology', region='DK1')

# %%
fig, ax = res_I_II.plot_profile(scenario='BaseCase', year=2050, commodity='Electricity', columns='Technology', region='DK1')

# %%
fig, ax = res_I_II.plot_profile(scenario='BaseCase', year=2050, commodity='Hydrogen', columns='Technology', region='DK1')

# %%
fig, ax = res_I_II.plot_profile(scenario='DR-1', year=2050, commodity='Hydrogen', columns='Technology', region='DK1')

# %%
fig, ax = res_I_II.plot_profile(scenario='DR-7', year=2050, commodity='Hydrogen', columns='Technology', region='DK1')

# %% [markdown]
# # Section II

# %% [markdown]
# ### Cap_H2_Uni

# %%
res_I_II.interactive_bar_chart()
# Out:
# Result type: balmorel
# GridBox(children=(Dropdown(description='Table:', layout=Layout(width='80%'), options=('F_CONS_YCRA', 'F_CONS_Y…
# Output()
# Stack(children=(GridBox(children=(SelectMultiple(description='Scenario', index=(0,), layout=Layout(height='99%…
# Output()
# ...
# Output()
# HBox()
# Output()
# ...
# Output()
# Output()

# %% [markdown]
# ### Prod_H2_Uni

# %%
res_I_II.interactive_bar_chart()
# Out:
# Result type: balmorel
# GridBox(children=(Dropdown(description='Table:', layout=Layout(width='80%'), options=('F_CONS_YCRA', 'F_CONS_Y…
# Output()
# Stack(children=(GridBox(children=(SelectMultiple(description='Scenario', index=(0,), layout=Layout(height='99%…
# Output()
# ...
# Output()
# HBox()
# Output()
# ...
# Output()
# Output()

# %% [markdown]
# ### Cap_El_Uni

# %%
res_I_II.interactive_bar_chart()
# Out:
# Result type: balmorel
# GridBox(children=(Dropdown(description='Table:', layout=Layout(width='80%'), options=('F_CONS_YCRA', 'F_CONS_Y…
# Output()
# Stack(children=(GridBox(children=(SelectMultiple(description='Scenario', index=(0,), layout=Layout(height='99%…
# Output()
# ...
# Output()
# HBox()
# Output()
# ...
# Output()
# Output()

# %% [markdown]
# ### Prod_El_Uni

# %%
res_I_II.interactive_bar_chart()
# Out:
# Result type: balmorel
# GridBox(children=(Dropdown(description='Table:', layout=Layout(width='80%'), options=('F_CONS_YCRA', 'F_CONS_Y…
# Output()
# Stack(children=(GridBox(children=(SelectMultiple(description='Scenario', index=(0,), layout=Layout(height='99%…
# Output()
# ...
# Output()
# HBox()
# Output()
# ...
# Output()
# Output()

# %% [markdown]
# ### Emi_Uni

# %%
res_I_II_opti.interactive_bar_chart()
# Out:
# Result type: optiflow
# GridBox(children=(Dropdown(description='Table:', layout=Layout(width='80%'), options=('ECO_INDIC', 'ECO_PROC_Y…
# Output()
# Stack(children=(GridBox(children=(SelectMultiple(description='Scenario', index=(0,), layout=Layout(height='99%…
# Output()
# ...
# Output()
# HBox()
# Output()
# ...
# Output()
# Output()

# %% [markdown]
# ### Cost_Uni

# %%
res_I_II_opti.interactive_bar_chart()
# Out:
# Result type: optiflow
# GridBox(children=(Dropdown(description='Table:', layout=Layout(width='80%'), options=('ECO_INDIC', 'ECO_PROC_Y…
# Output()
# Stack(children=(GridBox(children=(SelectMultiple(description='Scenario', index=(0,), layout=Layout(height='99%…
# Output()
# ...
# Output()
# HBox()
# Output()
# ...
# Output()
# Output()

# %% [markdown]
# ### Trans_El_Uni

# %%
res_I_II.interactive_bar_chart()
# Out:
# Result type: balmorel
# GridBox(children=(Dropdown(description='Table:', layout=Layout(width='80%'), options=('F_CONS_YCRA', 'F_CONS_Y…
# Output()
# Stack(children=(GridBox(children=(SelectMultiple(description='Scenario', index=(0,), layout=Layout(height='99%…
# Output()
# ...
# Output()
# HBox()
# Output()
# ...
# Output()
# Output()

# %% [markdown]
# ### Price_H2_

# %%
res_I_II.interactive_bar_chart()
# Out:
# Result type: balmorel
# GridBox(children=(Dropdown(description='Table:', layout=Layout(width='80%'), options=('F_CONS_YCRA', 'F_CONS_Y…
# Output()
# Stack(children=(GridBox(children=(SelectMultiple(description='Scenario', index=(0,), layout=Layout(height='99%…
# Output()
# ...
# Output()
# HBox()
# Output()
# ...
# Output()
# Output()

# %% [markdown]
# ### Trans_H2_Uni

# %%
res_I_II.interactive_bar_chart()
# Out:
# Result type: balmorel
# GridBox(children=(Dropdown(description='Table:', layout=Layout(width='80%'), options=('F_CONS_YCRA', 'F_CONS_Y…
# Output()
# Stack(children=(GridBox(children=(SelectMultiple(description='Scenario', index=(0,), layout=Layout(height='99%…
# Output()
# ...
# Output()
# HBox()
# Output()
# ...
# Output()
# Output()

# %% [markdown]
# ### Map_El_Uni

# %%
fig, ax = res_I_II.plot_map(scenario='BaseCase', year=2050, commodity='Electricity', lines='FlowYear', generation='Production'
                       , generation_var = 'FFF', 
                       generation_show_min = 10 ,  # Plot less categories in the legend, 8 for Base
                       line_width_max= 11, pie_radius_max = 1.3,
                       line_legend_cluster_values=[10, 25, 50, 100], pie_legend_cluster_values=[125, 250, 500, 1000])
# Out:
# Found MainResults in ../../main_results/current/MainResults/MainResults_4.gdx
# /Users/maxfavrot/Balmorel/pybalmorel_MaxF/src/pybalmorel/plotting/maps_balmorel.py:808: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_line_new = pd.concat([df_line_new, df_line.loc[[k]]], ignore_index=True)

# %% [markdown]
# ### Map_H2_Uni

# %%
fig, ax = res_I_II.plot_map(scenario='DR-1', year=2050, commodity='Hydrogen', lines='FlowYear', generation='Production'
                         ,line_width_max= 12, pie_radius_max = 1.5
                         , line_legend_cluster_values=[10, 30, 60, 100], pie_legend_cluster_values=[25, 50, 100, 200])
# Out:
# Found MainResults in ../../main_results/current/MainResults/MainResults_1.gdx
# /Users/maxfavrot/Balmorel/pybalmorel_MaxF/src/pybalmorel/plotting/maps_balmorel.py:808: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_line_new = pd.concat([df_line_new, df_line.loc[[k]]], ignore_index=True)

# %%
fig, ax = res_I_II.plot_profile(scenario='BaseCase', year=2050, commodity='Electricity', columns='Technology')

# %%
fig, ax = res_I_II.plot_profile(scenario='DR-1', year=2050, commodity='Electricity', columns='Technology')

# %%
fig, ax = res_I_II.plot_profile(scenario='DR-3', year=2050, commodity='Electricity', columns='Technology')

# %%
fig, ax = res_I_II.plot_profile(scenario='DR-5', year=2050, commodity='Electricity', columns='Technology')

# %%
fig, ax = res_I_II.plot_profile(scenario='DR-7', year=2050, commodity='Electricity', columns='Technology')

# %% [markdown]
# Electricity price, lower on avg?
# Variability? seems to be the same

# %%
fig, ax = res_I_II.plot_profile(scenario='BaseCase', year=2050, commodity='Hydrogen', columns='Technology')

# %%
fig, ax = res_I_II.plot_profile(scenario='DR-1', year=2050, commodity='Hydrogen', columns='Technology')

# %%
fig, ax = res_I_II.plot_profile(scenario='DR-3', year=2050, commodity='Hydrogen', columns='Technology')

# %%
fig, ax = res_I_II.plot_profile(scenario='DR-5', year=2050, commodity='Hydrogen', columns='Technology')

# %%
fig, ax = res_I_II.plot_profile(scenario='DR-7', year=2050, commodity='Hydrogen', columns='Technology')

# %% [markdown]
# # Section III

# %% [markdown]
# ### Map_H2_Private

# %%
fig, ax = res_III.plot_map(scenario='5_4', year=2050, commodity='Hydrogen', lines='FlowYear', generation='Production'
                         ,line_width_max= 7, pie_radius_max = 1.4
                         , line_legend_cluster_values=[10, 30, 60, 100], pie_legend_cluster_values=[25, 50, 100, 200])
# Out:
# Found MainResults in ../../main_results/current/MainResults/MainResults_5_4.gdx
# /Users/maxfavrot/Balmorel/pybalmorel_MaxF/src/pybalmorel/plotting/maps_balmorel.py:808: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_line_new = pd.concat([df_line_new, df_line.loc[[k]]], ignore_index=True)

# %%
fig, ax = res_III.plot_profile(scenario='Private', year=2030, commodity='Electricity', columns='Technology', region='DK1')

# %%
fig, ax = res_III.plot_profile(scenario='Private', year=2030, commodity='Hydrogen', columns='Technology', region='DK1')

# %%
fig, ax = res_III.plot_profile(scenario='Private', year=2050, commodity='Electricity', columns='Technology', region='DK1')

# %%
fig, ax = res_III.plot_profile(scenario='Private', year=2050, commodity='Hydrogen', columns='Technology', region='DK1')

# %% [markdown]
# ### Export CSV files

# %%
res_I_II.interactive_bar_chart()

# %%
res_III.interactive_bar_chart()
# Out:
# Result type: balmorel
# GridBox(children=(Dropdown(description='Table:', layout=Layout(width='80%'), options=('F_CONS_YCRA', 'F_CONS_Y…
# Output()
# Stack(children=(GridBox(children=(SelectMultiple(description='Scenario', index=(0,), layout=Layout(height='99%…
# Output()
# ...
# Output()
# HBox()
# Output()
# ...
# Output()
# Output()

# %%
res_I_II.df
# Out:
#        Scenario  Year Country Region Season  Time         Category Unit  \
# 0          DR-1  2030  NORWAY    NO1    S02  T073        EXOGENOUS  MWh
# 1          DR-1  2030  NORWAY    NO1    S02  T073      DIST_LOSSES  MWh
# 2          DR-1  2030  NORWAY    NO1    S02  T073     TRANS_LOSSES  MWh
# 3          DR-1  2030  NORWAY    NO1    S02  T076        EXOGENOUS  MWh
# 4          DR-1  2030  NORWAY    NO1    S02  T076      DIST_LOSSES  MWh
# ...         ...   ...     ...    ...    ...   ...              ...  ...
# 296766     DR-7  2050  CYPRUS     CY    S50  T133  ENDO_OTHERTRANS  MWh
# 296767     DR-7  2050  CYPRUS     CY    S50  T136    ENDO_FUELCELL  MWh
# 296768     DR-7  2050  CYPRUS     CY    S50  T139    ENDO_FUELCELL  MWh
# 296769     DR-7  2050  CYPRUS     CY    S50  T142    ENDO_INTERSTO  MWh
# 296770     DR-7  2050  CYPRUS     CY    S50  T142    ENDO_FUELCELL  MWh
#
#              Value
# 0        58.708415
# 1         0.894037
# 2         0.012985
# 3        58.708415
# ...

# %%
res_III.df
# Out:
#        Scenario  Year Country Region Season  Time         Category Unit  \
# 0        Public  2030  NORWAY    NO1    S02  T073        EXOGENOUS  MWh
# 1        Public  2030  NORWAY    NO1    S02  T073      DIST_LOSSES  MWh
# 2        Public  2030  NORWAY    NO1    S02  T073     TRANS_LOSSES  MWh
# 3        Public  2030  NORWAY    NO1    S02  T076        EXOGENOUS  MWh
# 4        Public  2030  NORWAY    NO1    S02  T076    ENDO_INTERSTO  MWh
# ...         ...   ...     ...    ...    ...   ...              ...  ...
# 178338      5_4  2050  CYPRUS     CY    S50  T133    ENDO_INTERSTO  MWh
# 178339      5_4  2050  CYPRUS     CY    S50  T133  ENDO_OTHERTRANS  MWh
# 178340      5_4  2050  CYPRUS     CY    S50  T136    ENDO_FUELCELL  MWh
# 178341      5_4  2050  CYPRUS     CY    S50  T139    ENDO_FUELCELL  MWh
# 178342      5_4  2050  CYPRUS     CY    S50  T142    ENDO_FUELCELL  MWh
#
#                Value
# 0       5.870841e+01
# 1       8.940368e-01
# 2      -3.084453e-15
# ...

# %%
# export res_I_II and res_III to csv files
res_I_II.df.to_csv('res_I_II_H2_DEM_ST.csv', index=False)
res_III.df.to_csv('res_III_H2_DEM_ST.csv', index=False)

# %%
res_III.interactive_bar_chart_countrygr_x()
# Out:
# Result type: balmorel
# GridBox(children=(Dropdown(description='Table:', layout=Layout(width='80%'), options=('F_CONS_YCRA', 'F_CONS_Y…
# Output()
# Stack(children=(GridBox(children=(SelectMultiple(description='Scenario', index=(0,), layout=Layout(height='99%…
# Output()
# ...
# Output()
# HBox()
# Output()
# ...
# Output()
# Output()
