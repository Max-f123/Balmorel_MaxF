# %% [markdown]
# ### Scenario 1 (Base Case): 4% Uniform DF (Why did you go for 4% in Balmorel ?) (avg 2000-2013)
# ### Scenario 2 (Low Case): 2% Uniform DF (2013 - 2022) (previously 2%)
# ### Scenario 3 (High Case): 9% Uniform DF (avg 1985-1995) (previously 7%)
# ### Scenario 4 (Country-specific Case): Annuity changed using external source

# %% [markdown]
# # Base Case scenario overview

# %% [markdown]
# ### Generation mix

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# group european countries per similarities

# %%
# group european countries per similarities
Iberia = ['Portugal', 'Spain']
UK = ['United Kingdom', 'Ireland']
Nordic = ['Norway', 'Sweden', 'Finland', 'Denmark', 'Iceland']
Baltic = ['Estonia', 'Latvia', 'Lithuania']
Benelux = ['Belgium', 'Netherlands', 'Luxembourg']
Central_Europe = ['Germany', 'Austria', 'Switzerland', 'Czech Republic', 'Poland', 'Slovakia', 'Hungary']
Southestern_Europe = ['Greece', 'Slovenia', 'Croatia', 'Bosnia and Herzegovina', 'Montenegro', 'Serbia', 'North Macedonia', 'Albania', 'Kosovo']
Eastern_Europe = ['Ukraine', 'Belarus', 'Moldova', 'Romania', 'Bulgaria']
Italy = ['Italy', 'Malta']
France = ['France', 'Monaco']

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Hydrogen capacity

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# In 2050, mostly electrolysis developped, with a predominence in western Europe (especiqlly Spain, France and UK). Also from estern countries. Imports from north africa and Ukraine.

# %% [markdown]
# ### H2 Flows

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# What are the demand assumptions? -> Theo demain

# %% [markdown]
# # Sensitivity to DR assumptions

# %% [markdown]
# ## Uniform Discount rate

# %% [markdown]
# ### Generation mix

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# check prod

# %% [markdown]
# Why more demand for H2 when DF is high?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Deander a rasmus
# et plus clair

# %% [markdown]
# Why so much more H2 storage for High DR?
# maybe because there is not enough demand?

# %% [markdown]
# ### Hydrogen capacity and generation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# prod total doit etre la meme, mais plus on va vers SMR, moins la cap totale est elevee

# %% [markdown]
# low DR, plus de SMR?

# %% [markdown]
# The more you incresase DR:
# - the more UK and france is shifted to Germany Poland and Italy
# - Iports are not a variable for now
# - the more SMR is used
# - the less echanges are made (car on peut mettre des SMR ou on veut)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# sans imports, qu'est ce que ca donne? Balopt.opt, sans 3rd countries
# grosse diff?

# %% [markdown]
# ### (Total emissions)
# rapide mais interessant (ordre de grandeur)

# %% [markdown]
# ### (Electricity prices)

# %% [markdown]
# ## Country specific discount rate

# %% [markdown]
# ### Scenarios:
# - Predicted DR according to litt
# - High DR in South Estern EU (a verifier)
# - Low DR in the Baltics
# - High DR in Southern EU (Russie?)
#
# chercher etudes
# les coupler?

# %% [markdown]
# Country groupings to do the analysis:
# - UK
# - France
# - Iberia (Sapin and Portugal)
# - Italy
# - Benelux
# - Germany
# - Poland
# - Central
# - Nordics (Denmark, Sweden, Norway)
# - Nord-East ()
# - South east
# - (Imports)

# %% [markdown]
# ### Maps illustrating the different DR accross countries
