# %%
import sys
import gams
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from statsmodels.nonparametric.smoothers_lowess import lowess
#import gdxpds
from pandas.api.types import CategoricalDtype

# Get the absolute path of the Pybalmorel folder
pybalmorel_path = os.path.abspath("/Users/maxfavrot/Balmorel/pybalmorel_MaxF")

# Set the correct path for GAMS
gams_path = "/Library/Frameworks/GAMS.framework/Versions/48/Resources"

# Add Pybalmorel to Python's module search path
if pybalmorel_path not in sys.path:
    sys.path.insert(0, pybalmorel_path)

# Now, you can import your modules
from src.pybalmorel import MainResults
from src.pybalmorel.utils import symbol_to_df

# Set environment variables
os.environ["PATH"] = gams_path + ":" + os.environ.get("PATH", "")
os.environ["DYLD_LIBRARY_PATH"] = gams_path + ":" + os.environ.get("DYLD_LIBRARY_PATH", "")

# %% [markdown]
# # Loading the data

# %% [markdown]
# ## Balmorel Results

# %% [markdown]
# ### Base

# %%
res_base = MainResults(files=['MainResults_B_4%.gdx'], paths='../../main_results/current/MainResults', scenario_names=['Base'])
# Out:
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_B_4%.gdx

# %% [markdown]
# ### Uniform

# %%
res_uni = MainResults(files=['MainResults_B_1.4%.gdx', 'MainResults_B_3.3%.gdx', 'MainResults_B_4%.gdx', 'MainResults_B_5.7%.gdx', 'MainResults_B_9%.gdx' ], paths='../../main_results/current/MainResults', scenario_names=['Low', 'Social', 'Base', 'Private', 'High'])
# Out:
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_B_1.4%.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_B_3.3%.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_B_4%.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_B_5.7%.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_B_9%.gdx

# %% [markdown]
# ### Country Specific

# %%
res_spe = MainResults(files=['MainResults_B_3.3%_SPE.gdx', 'MainResults_2.8.gdx', 'MainResults_B_5.7%_SPE.gdx', 'MainResults_5.4.gdx'], paths='../../main_results/current/MainResults', scenario_names=['Specific_S', 'Uniform_S', 'Specific_P', 'Uniform_P'])
# Out:
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_B_3.3%_SPE.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_2.8.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_B_5.7%_SPE.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_5.4.gdx

# %% [markdown]
# ## Demand

# %% [markdown]
# ### Uniform

# %%
res_uni_dem = MainResults(files=['MainResults_B_1.4%.gdx', 'MainResults_B_3.3%.gdx', 'MainResults_B_4%.gdx', 'MainResults_B_5.7%.gdx', 'MainResults_B_9%.gdx' ], paths='../../main_results/current/MainResults', scenario_names=['H2 Demand - Low Scenario', 'H2 Demand - Social Scenario', 'H2 Demand - Base Scenario', 'H2 Demand - Private Scenario', 'H2 Demand - High Scenario'])
# Out:
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_B_1.4%.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_B_3.3%.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_B_4%.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_B_5.7%.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_B_9%.gdx

# %% [markdown]
# ### Specific

# %%
res_dem_spe = MainResults(files=['MainResults_B_3.3%_SPE.gdx', 'MainResults_2.8.gdx', 'MainResults_B_5.7%_SPE.gdx', 'MainResults_5.4.gdx'], paths='../../main_results/current/MainResults', scenario_names=['H2 Demand - Specific_S Scenario', 'H2 Demand - Uniform_S Scenario', 'H2 Demand - Specific_P Scenario', 'H2 Demand - Uniform_P Scenario'])
# Out:
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_B_3.3%_SPE.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_2.8.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_B_5.7%_SPE.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_5.4.gdx

# %% [markdown]
# ## Optiflow Results

# %% [markdown]
# ### Uniform

# %%
res_uni_opti = MainResults(files=['MainResults_B_1.4%.gdx', 'MainResults_B_3.3%.gdx', 'MainResults_B_4%.gdx', 'MainResults_B_5.7%.gdx', 'MainResults_B_9%.gdx' ], paths='../../main_results/current/MainResults', scenario_names=['Low', 'Social', 'Base', 'Private', 'High'], result_type='optiflow' )
# Out:
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_B_1.4%.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_B_3.3%.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_B_4%.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_B_5.7%.gdx
# /Users/maxfavrot/Balmorel/main_results/current/MainResults/MainResults_B_9%.gdx

# %% [markdown]
# # Plots

# %% [markdown]
# ## GUI

# %% [markdown]
# ### Classique

# %%
res_base.interactive_bar_chart()
# Out:
# Result type: balmorel
# GridBox(children=(Dropdown(description='Table:', layout=Layout(width='80%'), options=('F_CONS_YCRA', 'F_CONS_Y…
# Output()
# Stack(children=(GridBox(children=(SelectMultiple(description='Scenario', index=(0,), layout=Layout(height='99%…
# Output()
# ...
# Output()
# HBox()
# Output()
# ...
# Output()
# Output()

# %% [markdown]
# ### Country grouping - Legend

# %%
res_uni.interactive_bar_chart_countrygr()
# Out:
# Result type: balmorel
# GridBox(children=(Dropdown(description='Table:', layout=Layout(width='80%'), options=('F_CONS_YCRA', 'F_CONS_Y…
# Output()
# Stack(children=(GridBox(children=(SelectMultiple(description='Scenario', index=(0,), layout=Layout(height='99%…
# Output()
# ...
# Output()
# HBox()
# Output()
# ...
# Output()
# Output()

# %% [markdown]
# ### Country grouping - X-axis

# %%
res_uni.interactive_bar_chart_countrygr_x()
# Out:
# Result type: balmorel
# GridBox(children=(Dropdown(description='Table:', layout=Layout(width='80%'), options=('F_CONS_YCRA', 'F_CONS_Y…
# Output()
# Stack(children=(GridBox(children=(SelectMultiple(description='Scenario', index=(0,), layout=Layout(height='99%…
# Output()
# ...
# Output()
# HBox()
# Output()
# ...
# Output()
# Output()

# %% [markdown]
# ## Maps

# %% [markdown]
# ### Elec Mix

# %%
fig, ax = res_uni.plot_map(scenario='Base', year=2050, commodity='Electricity', lines='Capacity', generation='Capacity'
                       , generation_var = 'FFF', 
                       #generation_show_min = 2   # Plot less categories in the legend
                       )
# Out:
# Found MainResults in ../../main_results/current/MainResults/MainResults_B_4%.gdx
# /Users/maxfavrot/Balmorel/pybalmorel_MaxF/src/pybalmorel/plotting/maps_balmorel.py:791: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_line_new = pd.concat([df_line_new, df_line.loc[[k]]], ignore_index=True)

# %% [markdown]
# ### H2 Mix

# %%
fig, ax = res_uni.plot_map(scenario='Base', year=2050, commodity='Hydrogen', lines='FlowYear', generation='Production'
                         ,line_width_max= 8, pie_radius_max = 1.5
                         , line_legend_cluster_values=[10, 30, 60, 100], pie_legend_cluster_values=[25, 50, 100, 200])
# Out:
# Found MainResults in ../../main_results/current/MainResults/MainResults_B_4%.gdx
# /Users/maxfavrot/Balmorel/pybalmorel_MaxF/src/pybalmorel/plotting/maps_balmorel.py:814: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_line_new = pd.concat([df_line_new, df_line.loc[[i]]], ignore_index=True)

# %% [markdown]
# ### H2 Demand

# %%
fig, ax = res_uni_dem.plot_map(scenario='H2 Demand - Base Scenario', year=2050, commodity='Hydrogen', background='H2 Demand'
,background_scale_tick = 20)
# Out:
# Found MainResults in ../../main_results/current/MainResults/MainResults_B_4%.gdx

# %% [markdown]
# ### Annexes

# %%
# Create a dictionary to map each country to a country group
#country_groupings = {
    #"Iberia": ["PORTUGAL", "SPAIN"],
    #"UK": ["IRELAND", "UNITED_KINGDOM"],
    #"Nordic countries": ["DENMARK", "FINLAND", "NORWAY", "SWEDEN"],
    #"Baltics": ["ESTONIA", "LATVIA", "LITHUANIA"],
    #"Central Europe": ["GERMANY", "LUXEMBOURG", "NETHERLANDS", "SWITZERLAND"],
    #"Eastern EU": ["AUSTRIA", "CZECH_REPUBLIC", "POLAND"],
    #"South Eastern EU": ["BULGARIA", "CROATIA", "CYPRUS", "GREECE", "HUNGARY", "MALTA", "ROMANIA", "SLOVAKIA", "SLOVENIA"],
    #"South Eastern non-EU": ["ALBANIA", "BOSNIA_AND_HERZEGOVINA", "NORTH_MACEDONIA", "MONTENEGRO", "SERBIA"],
    #"Mediterranean": ["ITALY"],
    #"Franco-Belgium": ["BELGIUM", "FRANCE"]
#}

# %%
#help(res_uni.plot_map)
